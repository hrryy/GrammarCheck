# %% [markdown]
# # Select by columns

# %%
import pandas as pd
pd.options.display.max_rows = None
pd.options.display.max_columns = None
df = pd.read_csv("domestic-stu.txt",sep=",")
df
# Out:
#       FirstName    LastName Province  CGPA  ResearchScore
# 0          Mary       White       BC  4.00             85
# 1          Mike       Hwang       ON  3.70             90
# 2          Liam     Edwards       AB  4.33             70
# 3          Noah     Collins       BC  4.20             71
# 4       William     Stewart       MB  4.10             72
# 5         James     Sanchez       NB  4.00             73
# 6        Oliver      Morris       NL  3.90             74
# 7      Benjamin      Rogers       NT  3.80             75
# 8        Elijah        Reed       NS  3.70             76
# 9         Lucas        Cook       NU  3.60             77
# 10        Mason      Morgan       ON  3.50             78
# 11        Logan        Bell       PE  3.40             79
# 12    Alexander      Murphy       QC  3.30             80
# 13        Ethan      Bailey       SK  3.20             81
# 14        Jacob      Rivera       YT  3.10             82
# ...

# %%
df["FirstName"]
# Out:
# 0            Mary
# 1            Mike
# 2            Liam
# 3            Noah
# 4         William
# 5           James
# 6          Oliver
# 7        Benjamin
# 8          Elijah
# 9           Lucas
# 10          Mason
# 11          Logan
# 12      Alexander
# 13          Ethan
# 14          Jacob
# 15        Michael
# 16         Daniel
# 17          Henry
# 18        Jackson
# 19      Sebastian
# 20          Aiden
# 21        Matthew
# 22         Samuel
# 23          David
# 24         Joseph
# 25         Carter
# 26           Owen
# 27          Wyatt
# 28           John
# 29           Jack
# 30           Luke
# 31         Jayden
# 32          Dylan
# 33        Grayson
# 34           Levi
# 35          Isaac
# 36        Gabriel
# 37         Julian
# 38          Mateo
# 39        Anthony
# 40          Jaxon
# 41        Lincoln
# 42         Joshua
# 43    Christopher
# 44         Andrew
# 45       Theodore
# 46          Caleb
# 47           Ryan
# 48          Asher
# 49         Nathan
# ...

# %%
df[["FirstName","CGPA","ResearchScore"]]
# Out:
#       FirstName  CGPA  ResearchScore
# 0          Mary  4.00             85
# 1          Mike  3.70             90
# 2          Liam  4.33             70
# 3          Noah  4.20             71
# 4       William  4.10             72
# 5         James  4.00             73
# 6        Oliver  3.90             74
# 7      Benjamin  3.80             75
# 8        Elijah  3.70             76
# 9         Lucas  3.60             77
# 10        Mason  3.50             78
# 11        Logan  3.40             79
# 12    Alexander  3.30             80
# 13        Ethan  3.20             81
# 14        Jacob  3.10             82
# 15      Michael  3.00             83
# 16       Daniel  2.90             84
# 17        Henry  2.80             85
# 18      Jackson  4.25             86
# 19    Sebastian  4.15             87
# 20        Aiden  4.05             88
# 21      Matthew  3.95             89
# 22       Samuel  3.85             90
# 23        David  3.75             91
# ...

# %%
df.columns
# Out:
# Index(['FirstName', 'LastName', 'Province', 'CGPA', 'ResearchScore'], dtype='object')

# %%
df[df.columns[[0,3,4]]]
# Out:
#       FirstName  CGPA  ResearchScore
# 0          Mary  4.00             85
# 1          Mike  3.70             90
# 2          Liam  4.33             70
# 3          Noah  4.20             71
# 4       William  4.10             72
# 5         James  4.00             73
# 6        Oliver  3.90             74
# 7      Benjamin  3.80             75
# 8        Elijah  3.70             76
# 9         Lucas  3.60             77
# 10        Mason  3.50             78
# 11        Logan  3.40             79
# 12    Alexander  3.30             80
# 13        Ethan  3.20             81
# 14        Jacob  3.10             82
# 15      Michael  3.00             83
# 16       Daniel  2.90             84
# 17        Henry  2.80             85
# 18      Jackson  4.25             86
# 19    Sebastian  4.15             87
# 20        Aiden  4.05             88
# 21      Matthew  3.95             89
# 22       Samuel  3.85             90
# 23        David  3.75             91
# ...

# %%
df[df.columns[-1]]
# Out:
# 0      85
# 1      90
# 2      70
# 3      71
# 4      72
# 5      73
# 6      74
# 7      75
# 8      76
# 9      77
# 10     78
# 11     79
# 12     80
# 13     81
# 14     82
# 15     83
# 16     84
# 17     85
# 18     86
# 19     87
# 20     88
# 21     89
# 22     90
# 23     91
# 24     92
# 25     93
# 26     94
# 27     95
# 28     96
# 29     97
# 30     98
# 31     99
# 32    100
# 33     99
# 34     98
# 35     97
# 36     96
# 37     95
# 38     94
# 39     93
# 40     92
# 41     91
# 42     90
# 43     89
# 44     88
# 45     87
# 46     86
# 47     85
# 48     84
# 49     83
# 50     82
# 51     81
# 52     80
# 53     79
# 54     78
# 55     77
# 56     76
# 57     75
# 58     74
# 59     73
# 60     72
# 61     71
# 62     70
# 63    100
# 64     99
# 65     98
# 66     97
# 67     96
# 68     95
# 69     94
# 70     93
# 71     92
# 72     91
# 73     90
# 74     89
# 75     88
# 76     87
# 77     86
# 78     85
# 79     84
# 80     83
# 81     82
# 82     81
# ...

# %%
df[df.columns[0]][:3]
# Out:
# 0    Mary
# 1    Mike
# 2    Liam
# Name: FirstName, dtype: object

# %%
df[df.columns[0]][67:]
# Out:
# 67       Sofia
# 68      Camila
# 69        Aria
# 70    Scarlett
# 71    Victoria
# 72     Madison
# 73        Luna
# 74       Grace
# 75       Chloe
# 76    Penelope
# 77       Layla
# 78       Riley
# 79        Zoey
# 80        Nora
# 81        Lily
# 82     Eleanor
# 83      Hannah
# 84     Lillian
# 85     Addison
# 86      Aubrey
# 87       Ellie
# 88      Stella
# 89     Natalie
# 90         Zoe
# 91        Leah
# 92       Hazel
# 93      Violet
# 94      Aurora
# 95    Savannah
# 96      Audrey
# 97    Brooklyn
# 98       Bella
# 99      Claire
# Name: FirstName, dtype: object

# %% [markdown]
# # Select by rows
# ### df.loc["index_name"]

# %%
df.loc[66]
# Out:
# FirstName         Avery
# LastName         Howard
# Province             YT
# CGPA                4.1
# ResearchScore        97
# Name: 66, dtype: object

# %%
df.loc[[34,45,19,20,88]]
# Out:
#     FirstName   LastName Province  CGPA  ResearchScore
# 34       Levi  Henderson       NS  4.20             98
# 45   Theodore    Simmons       NL  3.10             87
# 19  Sebastian       Ward       NL  4.15             87
# 20      Aiden     Torres       NT  4.05             88
# 88     Stella  Patterson       ON  3.45             75

# %%
df.loc[[34,45,19,20,88],"CGPA"]
# Out:
# 34    4.20
# 45    3.10
# 19    4.15
# 20    4.05
# 88    3.45
# Name: CGPA, dtype: float64

# %%
df.loc[[34,45,19,20,88],["FirstName", "LastName", "CGPA"]]
# Out:
#     FirstName   LastName  CGPA
# 34       Levi  Henderson  4.20
# 45   Theodore    Simmons  3.10
# 19  Sebastian       Ward  4.15
# 20      Aiden     Torres  4.05
# 88     Stella  Patterson  3.45

# %%
df.loc[35:87, df.columns[[0,1,3,4]]]
# Out:
#       FirstName    LastName  CGPA  ResearchScore
# 35        Isaac     Coleman  4.10             97
# 36      Gabriel     Jenkins  4.00             96
# 37       Julian       Perry  3.90             95
# 38        Mateo      Powell  3.80             94
# 39      Anthony        Long  3.70             93
# 40        Jaxon   Patterson  3.60             92
# 41      Lincoln      Hughes  3.50             91
# 42       Joshua      Flores  3.40             90
# 43  Christopher  Washington  3.30             89
# 44       Andrew      Butler  3.20             88
# 45     Theodore     Simmons  3.10             87
# 46        Caleb      Foster  3.00             86
# 47         Ryan    Gonzales  2.90             85
# 48        Asher      Bryant  2.80             84
# 49       Nathan   Alexander  4.25             83
# 50       Thomas     Russell  4.15             82
# 51         Emma     Griffin  4.05             81
# 52       Olivia     Stewart  3.95             80
# ...

# %% [markdown]
# # ILOC
# ##### index location

# %%
df.iloc[[0,2]]
# Out:
#           LastName Province  CGPA  ResearchScore
# FirstName
# Mary         White       BC  4.00             85
# Liam       Edwards       AB  4.33             70

# %%
df.iloc[0:2]
# Out:
#           LastName Province  CGPA  ResearchScore
# FirstName
# Mary         White       BC   4.0             85
# Mike         Hwang       ON   3.7             90
